# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/basic_python_programs/blob/main/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import Counter
lst = [34,54,23928,23923937]
result = Counter(lst)
print(result)
# Out:
# Counter({34: 1, 54: 1, 23928: 1, 23923937: 1})

# %%
s = "rishi"
result = Counter(s)
print(result)
# Out:
# Counter({'i': 2, 'r': 1, 's': 1, 'h': 1})
