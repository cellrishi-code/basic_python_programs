# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/basic_python_programs/blob/main/python_trick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = [1,2,3,4,5]    #trick 1
squares = [n**2 for n in num]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
list = ["python",'go','rust']    # trick 2
for index , value in enumerate(list , start = 1):     # default value of satrt is 0
    print(index,value)
# Out:
# 1 python
# 2 go
# 3 rust

# %%
#Every repetitive task you eliminate gives you more time to solve problems that actually matter.

# %%
data = []
def add_item(x):
    data.append(x)
                                 #in this we are adding the stuff from back so there is insert function to append from front
add_item(5)
add_item(6)

print(data)
# Out:
# [5, 6]

# %%
data = []
def add_itenm_front(x):
    data.insert(0,x)

add_itenm_front(3)
add_itenm_front(4)

print(data)
# Out:
# [4, 3]

# %%
my_list = [2, 3, 4]
my_list.insert(0, 1)  # Inserts '1' at index 0
print(my_list)        # Output: [1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
def clean_username(name):
    return name.strip().lower()

clean_username("           Rishi     Gupta"          )
# Out:
# 'rishi     gupta'

# %%
# strip = from both left and right
# lstrip = only from left (rstrip())
# title = captize the first world of every world
# captilzer = only the first letter of the world one only

# %% [markdown]
# ## File handing in python

# %% [markdown]
# # all important basic and function and code are given below

# %%
file = open("example.txt", "r")

# %%
content = file.read()
print(content)
# Out:
# this is my first notepad writing

# %%
file.close()

# %%
# read()==> read the whole file from top to buttom
# readline()==> read the file line by line

# %%
file = open("example.txt", "w")
file.write("Hello World")
file.close()

# %%
file = open("example.txt","r")
content = file.read()
print(content)
# Out:
# Hello World

# %%
import os

if os.path.exists("example.txt"):
    print("File exists")
else:
    print("Not found")
# Out:
# File exists

# %%
# import os
# os.remove("file name here")   --> this will delete the file
